# %%
## importing required libraries
import os
import shutil
import random

# %%
train_path = "/content/drive/MyDrive/YOLO_V5_OD/Vechicle_num_Data/train/images"
val_path = "/content/drive/MyDrive/YOLO_V5_OD/Vechicle_num_Data/val/images"
test_path = "/content/drive/MyDrive/YOLO_V5_OD/Vechicle_num_Data/test"

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %%
### change the dir to dyolov5
# %cd yolov5/

# %%
# !pip install -r requirements.txt

# %%
# !wget https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt

# %%
# !python train.py --img 416 --batch 8 --epochs 50 --data /content/drive/MyDrive/YOLO_V5_OD/Vechicle_num_Data/dataset.yaml --weights /content/yolov5/yolov5s.pt --nosave --cache

# %%
# !pip install tensorboard

# %%
# Start tensorboard
# Launch after you have started training
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
## inference or detection on new images
# !python detect.py --source /content/drive/MyDrive/YOLO_V5_OD/Vechicle_num_Data/test --weights /content/yolov5/runs/train/exp3/weights/best.pt --img 416 --save-txt --save-conf

# %%
# !pip install IPython

# %%
#display result images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'):
  print(imageName)
  display(Image(filename=imageName))
  print("\n")
